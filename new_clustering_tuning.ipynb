# %%
import pandas as pd
import numpy as np
from sklearn.metrics import silhouette_score, silhouette_samples
from collections import Counter
from scipy.stats import entropy
import warnings
warnings.filterwarnings('ignore')

from functions import join_stocks_crypto

# %%
df_all_stocks = pd.read_csv('stocks_data_filtered_volatility.csv',index_col='Date')
cryptos_df = pd.read_csv('cryptos_data.csv', index_col='Date')

joined_df = join_stocks_crypto(cryptos_df, df_all_stocks, mode = 'stocks_left') #mode - either do left with crypto and fill NA for stocks or do left on stocks and leave out some dates for cryptos
joined_df.index = pd.to_datetime(joined_df.index)

joined_df_weekly = joined_df.resample('W').last() #try aggregating on a weekly level
joined_df_3days = joined_df.resample('3D').last()# aggregating on a twice per week basis to arrive at the sweet spot of that 250 (1 year) timeseries length

# %%
def improved_clustering_tuning(df_dict, param_grid, n_trials=3, test_split=0.3):
    """
    Improved clustering hyperparameter tuning with proper validation.
    
    Parameters:
    -----------
    df_dict : dict
        Dictionary with dataframe name as key and stock prices dataframe as value
    param_grid : dict
        Grid of parameters to test, e.g.:
        {
            'n_clusters': [4, 6, 8, 10],
            'method': ['kmeans', 'ahc', 'kshape'],
            'linkage': ['average', 'complete', 'single'],  # Only for AHC
            'window': [1, 7, 14, 30],
            'aggregation': ['daily', '3day', 'weekly']
        }
    n_trials : int
        Number of random trials for stability testing
    test_split : float
        Fraction of data to hold out for validation
    
    Returns:
    --------
    pd.DataFrame
        Results with comprehensive metrics
    """
    
    results = []
    
    # Get available dataframes
    available_dfs = {
        'daily': df_dict.get('full', None),
        '3day': df_dict.get('3day', None), 
        'weekly': df_dict.get('weekly', None)
    }
    
    # Generate all parameter combinations
    param_combinations = _generate_param_combinations(param_grid)
    
    print(f"Testing {len(param_combinations)} parameter combinations...")
    
    for i, params in enumerate(param_combinations):
        if i % 10 == 0:
            print(f"Progress: {i}/{len(param_combinations)}")
            
        try:
            # Get the appropriate dataframe
            df = available_dfs.get(params['aggregation'])
            if df is None:
                continue
                
            # Run multiple trials for stability
            trial_results = []
            for trial in range(n_trials):
                trial_result = _evaluate_single_configuration(df, params, trial, test_split)
                if trial_result is not None:
                    trial_results.append(trial_result)
            
            # Aggregate trial results
            if trial_results:
                aggregated_result = _aggregate_trial_results(trial_results, params)
                results.append(aggregated_result)
                
        except Exception as e:
            print(f"Error with params {params}: {e}")
            continue
    
    return pd.DataFrame(results)

def _generate_param_combinations(param_grid):
    """Generate all combinations of parameters."""
    from itertools import product
    
    # Handle method-specific parameters
    combinations = []
    
    methods = param_grid.get('method', ['kmeans'])
    
    for method in methods:
        method_params = {
            'method': method,
            'n_clusters': param_grid.get('n_clusters', [6]),
            'window': param_grid.get('window', [1]),
            'aggregation': param_grid.get('aggregation', ['daily'])
        }
        
        # Add linkage only for AHC
        if method == 'ahc':
            method_params['linkage'] = param_grid.get('linkage', ['average'])
        else:
            method_params['linkage'] = ['not_applicable']
        
        # Generate combinations for this method
        keys = list(method_params.keys())
        values = list(method_params.values())
        
        for combination in product(*values):
            param_dict = dict(zip(keys, combination))
            combinations.append(param_dict)
    
    return combinations

def _evaluate_single_configuration(df, params, trial, test_split):
    """Evaluate a single parameter configuration."""
    
    # Apply smoothing (NO LOOK-AHEAD BIAS)
    if params['window'] > 1:
        df_smooth = df.rolling(window=params['window'], center=False).mean().dropna()
    else:
        df_smooth = df.copy()
    
    # Split data for validation
    split_idx = int(len(df_smooth) * (1 - test_split))
    df_train = df_smooth.iloc[:split_idx]
    df_test = df_smooth.iloc[split_idx:]
    
    # Ensure we have enough data
    if len(df_train) < 100 or len(df_test) < 50:
        return None
    
    try:
        # Train clustering model
        labels_train, tickers_labels_train, distance_matrix_train = _run_clustering_safe(
            df_train, params, trial_seed=trial
        )
        
        # Evaluate on training data
        train_metrics = _calculate_comprehensive_metrics(
            df_train, labels_train, tickers_labels_train, distance_matrix_train, params
        )
        
        # Evaluate stability on test data (if possible)
        try:
            labels_test, tickers_labels_test, distance_matrix_test = _run_clustering_safe(
                df_test, params, trial_seed=trial + 100
            )
            test_metrics = _calculate_comprehensive_metrics(
                df_test, labels_test, tickers_labels_test, distance_matrix_test, params
            )
            
            # Calculate stability score (how similar are train/test clusterings?)
            stability_score = _calculate_stability_score(tickers_labels_train, tickers_labels_test)
            
        except:
            test_metrics = None
            stability_score = None
        
        return {
            'trial': trial,
            'train_metrics': train_metrics,
            'test_metrics': test_metrics,
            'stability_score': stability_score,
            **params
        }
        
    except Exception as e:
        return None

def _run_clustering_safe(df, params, trial_seed):
    """Safely run clustering with error handling."""
    
    # Calculate returns
    df_returns = df.pct_change().dropna()
    data_clustering = df_returns.T.values
    tickers = list(df.columns)
    
    # Scale data
    from tslearn.preprocessing import TimeSeriesScalerMeanVariance
    scaler = TimeSeriesScalerMeanVariance()
    data_scaled = scaler.fit_transform(data_clustering)
    
    # Set random seed for reproducibility
    np.random.seed(trial_seed)
    
    method = params['method']
    n_clusters = params['n_clusters']
    
    if method == 'ahc':
        # Calculate distance matrix once
        distance_matrix = _calculate_dtw_matrix(data_scaled)
        
        from sklearn.cluster import AgglomerativeClustering
        model = AgglomerativeClustering(
            n_clusters=n_clusters, 
            metric='precomputed', 
            linkage=params['linkage']
        )
        labels = model.fit_predict(distance_matrix)
        
    elif method == 'kmeans':
        from tslearn.clustering import TimeSeriesKMeans
        model = TimeSeriesKMeans(
            n_clusters=n_clusters, 
            metric="dtw", 
            n_init=3, 
            init='random',
            random_state=trial_seed
        )
        labels = model.fit_predict(data_scaled)
        distance_matrix = None  # Will calculate if needed
        
    elif method == 'kshape':
        from tslearn.clustering import KShape
        model = KShape(
            n_clusters=n_clusters, 
            n_init=3,
            random_state=trial_seed
        )
        labels = model.fit_predict(data_scaled)
        distance_matrix = None  # Will calculate if needed
    
    # Create tickers to labels mapping
    tickers_with_labels = {ticker: int(label) for ticker, label in zip(tickers, labels)}
    
    return labels, tickers_with_labels, distance_matrix

def _calculate_dtw_matrix(data_scaled):
    """Calculate DTW distance matrix."""
    from tslearn.metrics import cdist_dtw
    return cdist_dtw(data_scaled)

def _calculate_comprehensive_metrics(df, labels, tickers_labels, distance_matrix, params):
    """Calculate comprehensive clustering metrics."""
    
    # Basic info
    n_assets = len(labels)
    n_clusters = len(set(labels))
    
    # Silhouette metrics
    if distance_matrix is not None:
        sil_score = silhouette_score(distance_matrix, labels, metric='precomputed')
        sil_samples = silhouette_samples(distance_matrix, labels, metric='precomputed')
    else:
        # Calculate distance matrix for silhouette
        df_returns = df.pct_change().dropna()
        data_scaled = df_returns.T.values
        try:
            distance_matrix = _calculate_dtw_matrix(data_scaled)
            sil_score = silhouette_score(distance_matrix, labels, metric='precomputed')
            sil_samples = silhouette_samples(distance_matrix, labels, metric='precomputed')
        except:
            sil_score = 0
            sil_samples = np.zeros(len(labels))
    
    # Balance metrics
    cluster_counts = Counter(labels)
    cluster_sizes = list(cluster_counts.values())
    
    # Advanced balance metrics
    cluster_proportions = np.array(cluster_sizes) / n_assets
    balance_entropy = entropy(cluster_proportions)
    max_entropy = np.log(n_clusters)
    normalized_entropy = balance_entropy / max_entropy if max_entropy > 0 else 0
    
    # Size metrics
    min_cluster_size = min(cluster_sizes)
    max_cluster_size = max(cluster_sizes)
    balance_ratio = min_cluster_size / max_cluster_size
    largest_cluster_pct = max_cluster_size / n_assets
    
    # Economic metrics (correlations within clusters)
    within_cluster_correlations = []
    df_returns = df.pct_change().dropna()
    
    for cluster_id in set(labels):
        cluster_assets = [ticker for ticker, label in tickers_labels.items() if label == cluster_id]
        if len(cluster_assets) >= 2:
            cluster_returns = df_returns[cluster_assets]
            corr_matrix = cluster_returns.corr()
            # Get upper triangle correlations
            mask = np.triu(np.ones_like(corr_matrix), k=1).astype(bool)
            correlations = corr_matrix.values[mask]
            within_cluster_correlations.extend(correlations)
    
    avg_within_cluster_corr = np.mean(within_cluster_correlations) if within_cluster_correlations else 0
    
    return {
        'silhouette_score': sil_score,
        'silhouette_std': np.std(sil_samples),
        'min_silhouette': np.min(sil_samples),
        'balance_entropy': normalized_entropy,
        'balance_ratio': balance_ratio,
        'largest_cluster_pct': largest_cluster_pct,
        'avg_within_cluster_corr': avg_within_cluster_corr,
        'n_clusters': n_clusters,
        'n_assets': n_assets
    }

def _calculate_stability_score(labels_1, labels_2):
    """Calculate stability between two clustering results."""
    # Use Adjusted Rand Index
    from sklearn.metrics import adjusted_rand_score
    
    # Get common assets
    common_assets = set(labels_1.keys()) & set(labels_2.keys())
    if len(common_assets) < 2:
        return 0
    
    labels_1_common = [labels_1[asset] for asset in common_assets]
    labels_2_common = [labels_2[asset] for asset in common_assets]
    
    return adjusted_rand_score(labels_1_common, labels_2_common)

def _aggregate_trial_results(trial_results, params):
    """Aggregate results across multiple trials."""
    
    # Extract training metrics
    train_metrics = [trial['train_metrics'] for trial in trial_results]
    
    # Calculate means and stds
    aggregated = {}
    for key in train_metrics[0].keys():
        values = [tm[key] for tm in train_metrics]
        aggregated[f'{key}_mean'] = np.mean(values)
        aggregated[f'{key}_std'] = np.std(values)
    
    # Stability scores
    stability_scores = [trial['stability_score'] for trial in trial_results if trial['stability_score'] is not None]
    if stability_scores:
        aggregated['stability_mean'] = np.mean(stability_scores)
        aggregated['stability_std'] = np.std(stability_scores)
    else:
        aggregated['stability_mean'] = None
        aggregated['stability_std'] = None
    
    # Add parameters
    aggregated.update(params)
    aggregated['n_trials'] = len(trial_results)
    
    return aggregated

# Usage example:

param_grid = {
    'n_clusters': [4, 6, 8, 10, 12],
    'method': ['kmeans', 'ahc', 'kshape'],
    'linkage': ['average', 'complete', 'single'],
    'window': [1, 7, 14, 30],
    'aggregation': ['daily', '3day', 'weekly']
}

df_dict = {
    'full': joined_df,
    '3day': joined_df_3days, 
    'weekly': joined_df_weekly
}

results = improved_clustering_tuning(df_dict, param_grid, n_trials=3)
results.to_csv('improved_clustering_results.csv', index=False)
# Out:
# Testing 1260 parameter combinations...
# Progress: 0/1260
# Progress: 10/1260
# Progress: 20/1260
# Progress: 30/1260
# Progress: 40/1260
# Progress: 50/1260
# Progress: 60/1260
# Progress: 70/1260
# Progress: 80/1260
# Progress: 90/1260
# Progress: 100/1260
# Progress: 110/1260
# Progress: 120/1260
# Progress: 130/1260
# Progress: 140/1260
# Progress: 150/1260
# Progress: 160/1260
# Progress: 170/1260
# Progress: 180/1260
# Progress: 190/1260
# Progress: 200/1260
# Progress: 210/1260
# Progress: 220/1260
# Progress: 230/1260
# Progress: 240/1260
# Progress: 250/1260
# Progress: 260/1260
# Progress: 270/1260
# Progress: 280/1260
# Progress: 290/1260
# Progress: 300/1260
# Progress: 310/1260
# Progress: 320/1260
# Progress: 330/1260
# Progress: 340/1260
# Progress: 350/1260
# Progress: 360/1260
# Progress: 370/1260
# Progress: 380/1260
# Progress: 390/1260
# Progress: 400/1260
# Progress: 410/1260
# Progress: 420/1260
# Progress: 430/1260
# Progress: 440/1260
# Progress: 450/1260
# Progress: 460/1260
# Progress: 470/1260
# Progress: 480/1260
# Progress: 490/1260
# Progress: 500/1260
# Progress: 510/1260
# Progress: 520/1260
# Progress: 530/1260
# Progress: 540/1260
# Progress: 550/1260
# Progress: 560/1260
# Progress: 570/1260
# Progress: 580/1260
# Progress: 590/1260
# Progress: 600/1260
# Progress: 610/1260
# Progress: 620/1260
# Progress: 630/1260
# Progress: 640/1260
# Progress: 650/1260
# Progress: 660/1260
# Progress: 670/1260
# Progress: 680/1260
# Progress: 690/1260
# Progress: 700/1260
# Progress: 710/1260
# Progress: 720/1260
# Progress: 730/1260
# Progress: 740/1260
# Progress: 750/1260
# Progress: 760/1260
# Progress: 770/1260
# Progress: 780/1260
# Progress: 790/1260
# Progress: 800/1260
# Progress: 810/1260
# Progress: 820/1260
# Progress: 830/1260
# Progress: 840/1260
# Progress: 850/1260
# Progress: 860/1260
# Progress: 870/1260
# Progress: 880/1260
# Progress: 890/1260
# Progress: 900/1260
# Progress: 910/1260
# Progress: 920/1260
# Progress: 930/1260
# Progress: 940/1260
# Progress: 950/1260
# Progress: 960/1260
# Progress: 970/1260
# Progress: 980/1260
# Progress: 990/1260
# Progress: 1000/1260
# Progress: 1010/1260
# Progress: 1020/1260
# Progress: 1030/1260
# Progress: 1040/1260
# Progress: 1050/1260
# Progress: 1060/1260
# Progress: 1070/1260
# Progress: 1080/1260
# Progress: 1090/1260
# Progress: 1100/1260
# Progress: 1110/1260
# Progress: 1120/1260
# Progress: 1130/1260
# Progress: 1140/1260
# Progress: 1150/1260
# Progress: 1160/1260
# Progress: 1170/1260
# Progress: 1180/1260
# Progress: 1190/1260
# Progress: 1200/1260
# Progress: 1210/1260
# Progress: 1220/1260
# Progress: 1230/1260
# Progress: 1240/1260
# Progress: 1250/1260

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import silhouette_score, silhouette_samples
from collections import Counter
from scipy.stats import entropy
import warnings
warnings.filterwarnings('ignore')

def debug_clustering_tuning(df_dict, param_grid, n_trials=1, verbose=True):
    """
    Simplified clustering tuning with extensive debugging.
    
    Parameters:
    -----------
    df_dict : dict
        Dictionary with dataframe name as key and stock prices dataframe as value
    param_grid : dict
        Grid of parameters to test
    n_trials : int
        Number of trials (start with 1 for debugging)
    verbose : bool
        Print debug information
    
    Returns:
    --------
    pd.DataFrame
        Results with comprehensive metrics
    """
    
    print("=== DEBUGGING CLUSTERING TUNING ===")
    print(f"Available dataframes: {list(df_dict.keys())}")
    for name, df in df_dict.items():
        print(f"  {name}: {df.shape}")
    
    print(f"Parameter grid: {param_grid}")
    
    results = []
    
    # Simple parameter iteration - no complex combinations
    methods = param_grid.get('method', ['kmeans'])
    n_clusters_list = param_grid.get('n_clusters', [6])
    windows = param_grid.get('window', [1])
    aggregations = param_grid.get('aggregation', ['daily'])
    linkages = param_grid.get('linkage', ['average'])
    
    total_combinations = len(methods) * len(n_clusters_list) * len(windows) * len(aggregations)
    print(f"Total combinations to test: {total_combinations}")
    
    combination_count = 0
    
    for method in methods:
        for n_clusters in n_clusters_list:
            for window in windows:
                for aggregation in aggregations:
                    # Handle linkage
                    if method == 'ahc':
                        linkage_list = linkages
                    else:
                        linkage_list = ['not_applicable']
                    
                    for linkage in linkage_list:
                        combination_count += 1
                        
                        params = {
                            'method': method,
                            'n_clusters': n_clusters,
                            'window': window,
                            'aggregation': aggregation,
                            'linkage': linkage
                        }
                        
                        if verbose:
                            print(f"\n--- Combination {combination_count}/{total_combinations} ---")
                            print(f"Params: {params}")
                        
                        try:
                            # Get dataframe
                            df = _get_dataframe(df_dict, aggregation, verbose)
                            if df is None:
                                if verbose:
                                    print("  ❌ Dataframe not found")
                                continue
                            
                            # Test the combination
                            result = _test_single_combination(df, params, n_trials, verbose)
                            
                            if result is not None:
                                results.append(result)
                                if verbose:
                                    print(f"  ✅ Success! Silhouette: {result.get('silhouette_score', 'N/A'):.3f}")
                            else:
                                if verbose:
                                    print("  ❌ Failed to get result")
                                    
                        except Exception as e:
                            if verbose:
                                print(f"  ❌ Error: {str(e)}")
                            continue
    
    print(f"\n=== SUMMARY ===")
    print(f"Total combinations tested: {combination_count}")
    print(f"Successful results: {len(results)}")
    
    return pd.DataFrame(results)

def _get_dataframe(df_dict, aggregation, verbose=False):
    """Get the right dataframe based on aggregation."""
    
    # Mapping between aggregation names and df_dict keys
    mapping = {
        'daily': ['full', 'daily'],
        '3day': ['3day'],
        'weekly': ['weekly']
    }
    
    possible_keys = mapping.get(aggregation, [aggregation])
    
    for key in possible_keys:
        if key in df_dict:
            if verbose:
                print(f"  Using dataframe '{key}' for aggregation '{aggregation}'")
            return df_dict[key]
    
    if verbose:
        print(f"  No dataframe found for aggregation '{aggregation}'. Available: {list(df_dict.keys())}")
    return None

def _test_single_combination(df, params, n_trials, verbose=False):
    """Test a single parameter combination."""
    
    try:
        # Apply smoothing
        if params['window'] > 1:
            df_smooth = df.rolling(window=params['window']).mean().dropna()
            if verbose:
                print(f"  Applied {params['window']}-period smoothing: {df.shape} → {df_smooth.shape}")
        else:
            df_smooth = df.copy()
        
        # Check data size
        if len(df_smooth) < 50:
            if verbose:
                print(f"  ❌ Not enough data: {len(df_smooth)} rows")
            return None
        
        # Run clustering
        result = _run_simple_clustering(df_smooth, params, verbose)
        
        if result is not None:
            result.update(params)  # Add parameters to result
            
        return result
        
    except Exception as e:
        if verbose:
            print(f"  ❌ Exception in _test_single_combination: {str(e)}")
        return None

def _run_simple_clustering(df, params, verbose=False):
    """Run clustering and calculate metrics."""
    
    try:
        # Calculate returns
        df_returns = df.pct_change().dropna()
        
        if len(df_returns) < 20:
            if verbose:
                print("  ❌ Not enough return data")
            return None
            
        # Get data for clustering
        data_clustering = df_returns.T.values  # Assets as rows, time as columns
        tickers = list(df.columns)
        
        if verbose:
            print(f"  Data shape for clustering: {data_clustering.shape}")
        
        # Scale data
        try:
            from tslearn.preprocessing import TimeSeriesScalerMeanVariance
            scaler = TimeSeriesScalerMeanVariance()
            data_scaled = scaler.fit_transform(data_clustering)
        except:
            # Fallback to sklearn scaler
            from sklearn.preprocessing import StandardScaler
            scaler = StandardScaler()
            data_scaled = scaler.fit_transform(data_clustering)
        
        # Run clustering based on method
        labels = _run_clustering_method(data_scaled, params, verbose)
        
        if labels is None:
            return None
        
        # Calculate metrics
        metrics = _calculate_simple_metrics(data_scaled, labels, verbose)
        
        if metrics is not None:
            metrics['n_assets'] = len(tickers)
            metrics['n_clusters_actual'] = len(set(labels))
            
        return metrics
        
    except Exception as e:
        if verbose:
            print(f"  ❌ Exception in _run_simple_clustering: {str(e)}")
        return None

def _run_clustering_method(data_scaled, params, verbose=False):
    """Run the actual clustering algorithm."""
    
    method = params['method']
    n_clusters = params['n_clusters']
    
    try:
        if method == 'kmeans':
            try:
                from tslearn.clustering import TimeSeriesKMeans
                model = TimeSeriesKMeans(
                    n_clusters=n_clusters, 
                    metric="dtw", 
                    n_init=1,  # Reduce for debugging
                    init='random',
                    random_state=42
                )
                labels = model.fit_predict(data_scaled)
            except Exception as e:
                if verbose:
                    print(f"  TSLearn KMeans failed: {e}, trying sklearn...")
                # Fallback to regular KMeans
                from sklearn.cluster import KMeans
                model = KMeans(n_clusters=n_clusters, random_state=42, n_init=1)
                labels = model.fit_predict(data_scaled.reshape(data_scaled.shape[0], -1))
                
        elif method == 'ahc':
            from sklearn.cluster import AgglomerativeClustering
            
            # Use euclidean distance for now (DTW too slow for debugging)
            model = AgglomerativeClustering(
                n_clusters=n_clusters, 
                linkage=params['linkage']
            )
            data_flat = data_scaled.reshape(data_scaled.shape[0], -1)
            labels = model.fit_predict(data_flat)
            
        elif method == 'kshape':
            try:
                from tslearn.clustering import KShape
                model = KShape(n_clusters=n_clusters, n_init=1, random_state=42)
                labels = model.fit_predict(data_scaled)
            except Exception as e:
                if verbose:
                    print(f"  KShape failed: {e}, trying sklearn KMeans...")
                from sklearn.cluster import KMeans
                model = KMeans(n_clusters=n_clusters, random_state=42, n_init=1)
                labels = model.fit_predict(data_scaled.reshape(data_scaled.shape[0], -1))
        
        else:
            if verbose:
                print(f"  ❌ Unknown method: {method}")
            return None
        
        if verbose:
            print(f"  Clustering successful. Labels: {Counter(labels)}")
            
        return labels
        
    except Exception as e:
        if verbose:
            print(f"  ❌ Clustering failed: {str(e)}")
        return None

def _calculate_simple_metrics(data_scaled, labels, verbose=False):
    """Calculate basic metrics."""
    
    try:
        # Flatten data for distance calculation
        data_flat = data_scaled.reshape(data_scaled.shape[0], -1)
        
        # Silhouette score
        if len(set(labels)) > 1 and len(labels) > len(set(labels)):
            sil_score = silhouette_score(data_flat, labels)
        else:
            sil_score = -1  # Invalid clustering
        
        # Balance metrics
        cluster_counts = Counter(labels)
        cluster_sizes = list(cluster_counts.values())
        
        min_size = min(cluster_sizes)
        max_size = max(cluster_sizes)
        balance_ratio = min_size / max_size if max_size > 0 else 0
        
        # Entropy
        n_assets = len(labels)
        cluster_proportions = np.array(cluster_sizes) / n_assets
        balance_entropy = entropy(cluster_proportions)
        max_entropy = np.log(len(cluster_sizes))
        normalized_entropy = balance_entropy / max_entropy if max_entropy > 0 else 0
        
        metrics = {
            'silhouette_score': sil_score,
            'balance_ratio': balance_ratio,
            'balance_entropy': normalized_entropy,
            'largest_cluster_pct': max_size / n_assets,
            'cluster_counts': dict(cluster_counts)
        }
        
        if verbose:
            print(f"  Silhouette: {sil_score:.3f}, Balance ratio: {balance_ratio:.3f}")
            
        return metrics
        
    except Exception as e:
        if verbose:
            print(f"  ❌ Metrics calculation failed: {str(e)}")
        return None

# Simple test function
def test_clustering_simple(df_dict):
    """Simple test with minimal parameters."""
    
    param_grid = {
        'method': ['kmeans'],
        'n_clusters': [4, 6],
        'window': [1, 7],
        'aggregation': ['daily']
    }
    
    return debug_clustering_tuning(df_dict, param_grid, n_trials=1, verbose=True)

# Usage example:

# Test with your data
df_dict = {
    'full': joined_df,  # Make sure this matches your variable name
    '3day': joined_df_3days, 
    'weekly': joined_df_weekly
}

# Simple test first
results = test_clustering_simple(df_dict)
print(results)

# If that works, try the full grid
param_grid = {
    'method': ['kmeans', 'ahc'],
    'n_clusters': [4, 6, 8, 10],
    'window': [1, 7, 14],
    'aggregation': ['daily', '3day'],
    'linkage': ['average', 'complete']
}

full_results = debug_clustering_tuning(df_dict, param_grid, n_trials=1, verbose=True)
# Out:
# === DEBUGGING CLUSTERING TUNING ===
# Available dataframes: ['full', '3day', 'weekly']
#   full: (520, 213)
#   3day: (242, 213)
#   weekly: (104, 213)
# Parameter grid: {'method': ['kmeans'], 'n_clusters': [4, 6], 'window': [1, 7], 'aggregation': ['daily']}
# Total combinations to test: 4
#
# --- Combination 1/4 ---
# Params: {'method': 'kmeans', 'n_clusters': 4, 'window': 1, 'aggregation': 'daily', 'linkage': 'not_applicable'}
#   Using dataframe 'full' for aggregation 'daily'
#   Data shape for clustering: (213, 519)
#   Clustering successful. Labels: Counter({np.int64(2): 92, np.int64(1): 59, np.int64(0): 50, np.int64(3): 12})
#   Silhouette: 0.037, Balance ratio: 0.130
#   ✅ Success! Silhouette: 0.037
#
# --- Combination 2/4 ---
# Params: {'method': 'kmeans', 'n_clusters': 4, 'window': 7, 'aggregation': 'daily', 'linkage': 'not_applicable'}
#   Using dataframe 'full' for aggregation 'daily'
#   Applied 7-period smoothing: (520, 213) → (514, 213)
#   Data shape for clustering: (213, 513)
#   Clustering successful. Labels: Counter({np.int64(0): 72, np.int64(2): 64, np.int64(3): 46, np.int64(1): 31})
#   Silhouette: 0.030, Balance ratio: 0.431
#   ✅ Success! Silhouette: 0.030
#
# --- Combination 3/4 ---
# Params: {'method': 'kmeans', 'n_clusters': 6, 'window': 1, 'aggregation': 'daily', 'linkage': 'not_applicable'}
#   Using dataframe 'full' for aggregation 'daily'
#   Data shape for clustering: (213, 519)
#   Clustering successful. Labels: Counter({np.int64(1): 57, np.int64(2): 54, np.int64(0): 41, np.int64(5): 37, np.int64(3): 12, np.int64(4): 12})
#   Silhouette: 0.045, Balance ratio: 0.211
#   ✅ Success! Silhouette: 0.045
#
# --- Combination 4/4 ---
# Params: {'method': 'kmeans', 'n_clusters': 6, 'window': 7, 'aggregation': 'daily', 'linkage': 'not_applicable'}
#   Using dataframe 'full' for aggregation 'daily'
#   Applied 7-period smoothing: (520, 213) → (514, 213)
#   Data shape for clustering: (213, 513)
#   Clustering successful. Labels: Counter({np.int64(2): 64, np.int64(4): 49, np.int64(3): 43, np.int64(0): 29, np.int64(1): 18, np.int64(5): 10})
#   Silhouette: 0.027, Balance ratio: 0.156
#   ✅ Success! Silhouette: 0.027
#
# === SUMMARY ===
# Total combinations tested: 4
# Successful results: 4
#    silhouette_score  balance_ratio  balance_entropy  largest_cluster_pct  \
# 0          0.037394       0.130435         0.880369             0.431925
# 1          0.029812       0.430556         0.966185             0.338028
# 2          0.044893       0.210526         0.918650             0.267606
# 3          0.027458       0.156250         0.918791             0.300469
#
#                                cluster_counts  n_assets  n_clusters_actual  \
# 0                {2: 92, 3: 12, 0: 50, 1: 59}       213                  4
# 1                {0: 72, 3: 46, 1: 31, 2: 64}       213                  4
# 2  {2: 54, 3: 12, 0: 41, 1: 57, 5: 37, 4: 12}       213                  6
# 3  {0: 29, 3: 43, 4: 49, 2: 64, 5: 10, 1: 18}       213                  6
#
#    method  n_clusters  window aggregation         linkage
# 0  kmeans           4       1       daily  not_applicable
# 1  kmeans           4       7       daily  not_applicable
# 2  kmeans           6       1       daily  not_applicable
# 3  kmeans           6       7       daily  not_applicable
# === DEBUGGING CLUSTERING TUNING ===
# Available dataframes: ['full', '3day', 'weekly']
#   full: (520, 213)
#   3day: (242, 213)
#   weekly: (104, 213)
# Parameter grid: {'method': ['kmeans', 'ahc'], 'n_clusters': [4, 6, 8, 10], 'window': [1, 7, 14], 'aggregation': ['daily', '3day'], 'linkage': ['average', 'complete']}
# Total combinations to test: 48
#
# --- Combination 1/48 ---
# Params: {'method': 'kmeans', 'n_clusters': 4, 'window': 1, 'aggregation': 'daily', 'linkage': 'not_applicable'}
#   Using dataframe 'full' for aggregation 'daily'
#   Data shape for clustering: (213, 519)
#   Clustering successful. Labels: Counter({np.int64(2): 92, np.int64(1): 59, np.int64(0): 50, np.int64(3): 12})
#   Silhouette: 0.037, Balance ratio: 0.130
#   ✅ Success! Silhouette: 0.037
#
# --- Combination 2/48 ---
# Params: {'method': 'kmeans', 'n_clusters': 4, 'window': 1, 'aggregation': '3day', 'linkage': 'not_applicable'}
#   Using dataframe '3day' for aggregation '3day'
#   Data shape for clustering: (213, 241)
#   Clustering successful. Labels: Counter({np.int64(0): 77, np.int64(2): 75, np.int64(3): 41, np.int64(1): 20})
#   Silhouette: 0.040, Balance ratio: 0.260
#   ✅ Success! Silhouette: 0.040
#
# --- Combination 3/48 ---
# Params: {'method': 'kmeans', 'n_clusters': 4, 'window': 7, 'aggregation': 'daily', 'linkage': 'not_applicable'}
#   Using dataframe 'full' for aggregation 'daily'
#   Applied 7-period smoothing: (520, 213) → (514, 213)
#   Data shape for clustering: (213, 513)
#   Clustering successful. Labels: Counter({np.int64(0): 72, np.int64(2): 64, np.int64(3): 46, np.int64(1): 31})
#   Silhouette: 0.030, Balance ratio: 0.431
#   ✅ Success! Silhouette: 0.030
#
# --- Combination 4/48 ---
# Params: {'method': 'kmeans', 'n_clusters': 4, 'window': 7, 'aggregation': '3day', 'linkage': 'not_applicable'}
#   Using dataframe '3day' for aggregation '3day'
#   Applied 7-period smoothing: (242, 213) → (236, 213)
#   Data shape for clustering: (213, 235)
#   Clustering successful. Labels: Counter({np.int64(3): 71, np.int64(2): 68, np.int64(0): 49, np.int64(1): 25})
#   Silhouette: 0.023, Balance ratio: 0.352
#   ✅ Success! Silhouette: 0.023
#
# --- Combination 5/48 ---
# Params: {'method': 'kmeans', 'n_clusters': 4, 'window': 14, 'aggregation': 'daily', 'linkage': 'not_applicable'}
#   Using dataframe 'full' for aggregation 'daily'
#   Applied 14-period smoothing: (520, 213) → (507, 213)
#   Data shape for clustering: (213, 506)
#   Clustering successful. Labels: Counter({np.int64(3): 78, np.int64(2): 66, np.int64(0): 59, np.int64(1): 10})
#   Silhouette: 0.039, Balance ratio: 0.128
#   ✅ Success! Silhouette: 0.039
#
# --- Combination 6/48 ---
# Params: {'method': 'kmeans', 'n_clusters': 4, 'window': 14, 'aggregation': '3day', 'linkage': 'not_applicable'}
#   Using dataframe '3day' for aggregation '3day'
#   Applied 14-period smoothing: (242, 213) → (229, 213)
#   Data shape for clustering: (213, 228)
#   Clustering successful. Labels: Counter({np.int64(2): 78, np.int64(3): 55, np.int64(0): 55, np.int64(1): 25})
#   Silhouette: 0.002, Balance ratio: 0.321
#   ✅ Success! Silhouette: 0.002
#
# --- Combination 7/48 ---
# Params: {'method': 'kmeans', 'n_clusters': 6, 'window': 1, 'aggregation': 'daily', 'linkage': 'not_applicable'}
#   Using dataframe 'full' for aggregation 'daily'
#   Data shape for clustering: (213, 519)
#   Clustering successful. Labels: Counter({np.int64(1): 57, np.int64(2): 54, np.int64(0): 41, np.int64(5): 37, np.int64(3): 12, np.int64(4): 12})
#   Silhouette: 0.045, Balance ratio: 0.211
#   ✅ Success! Silhouette: 0.045
#
# --- Combination 8/48 ---
# Params: {'method': 'kmeans', 'n_clusters': 6, 'window': 1, 'aggregation': '3day', 'linkage': 'not_applicable'}
#   Using dataframe '3day' for aggregation '3day'
#   Data shape for clustering: (213, 241)
#   Clustering successful. Labels: Counter({np.int64(0): 66, np.int64(2): 56, np.int64(3): 40, np.int64(1): 22, np.int64(5): 20, np.int64(4): 9})
#   Silhouette: 0.016, Balance ratio: 0.136
#   ✅ Success! Silhouette: 0.016
#
# --- Combination 9/48 ---
# Params: {'method': 'kmeans', 'n_clusters': 6, 'window': 7, 'aggregation': 'daily', 'linkage': 'not_applicable'}
#   Using dataframe 'full' for aggregation 'daily'
#   Applied 7-period smoothing: (520, 213) → (514, 213)
#   Data shape for clustering: (213, 513)
#   Clustering successful. Labels: Counter({np.int64(2): 64, np.int64(4): 49, np.int64(3): 43, np.int64(0): 29, np.int64(1): 18, np.int64(5): 10})
#   Silhouette: 0.027, Balance ratio: 0.156
#   ✅ Success! Silhouette: 0.027
#
# --- Combination 10/48 ---
# Params: {'method': 'kmeans', 'n_clusters': 6, 'window': 7, 'aggregation': '3day', 'linkage': 'not_applicable'}
#   Using dataframe '3day' for aggregation '3day'
#   Applied 7-period smoothing: (242, 213) → (236, 213)
#   Data shape for clustering: (213, 235)
#   Clustering successful. Labels: Counter({np.int64(2): 61, np.int64(4): 40, np.int64(0): 39, np.int64(3): 39, np.int64(1): 18, np.int64(5): 16})
#   Silhouette: 0.010, Balance ratio: 0.262
#   ✅ Success! Silhouette: 0.010
#
# --- Combination 11/48 ---
# Params: {'method': 'kmeans', 'n_clusters': 6, 'window': 14, 'aggregation': 'daily', 'linkage': 'not_applicable'}
#   Using dataframe 'full' for aggregation 'daily'
#   Applied 14-period smoothing: (520, 213) → (507, 213)
#   Data shape for clustering: (213, 506)
#   Clustering successful. Labels: Counter({np.int64(4): 64, np.int64(2): 62, np.int64(0): 58, np.int64(5): 14, np.int64(1): 11, np.int64(3): 4})
#   Silhouette: 0.007, Balance ratio: 0.062
#   ✅ Success! Silhouette: 0.007
#
# --- Combination 12/48 ---
# Params: {'method': 'kmeans', 'n_clusters': 6, 'window': 14, 'aggregation': '3day', 'linkage': 'not_applicable'}
#   Using dataframe '3day' for aggregation '3day'
#   Applied 14-period smoothing: (242, 213) → (229, 213)
#   Data shape for clustering: (213, 228)
#   Clustering successful. Labels: Counter({np.int64(4): 63, np.int64(2): 63, np.int64(0): 37, np.int64(3): 28, np.int64(1): 13, np.int64(5): 9})
#   Silhouette: 0.010, Balance ratio: 0.143
#   ✅ Success! Silhouette: 0.010
#
# --- Combination 13/48 ---
# Params: {'method': 'kmeans', 'n_clusters': 8, 'window': 1, 'aggregation': 'daily', 'linkage': 'not_applicable'}
#   Using dataframe 'full' for aggregation 'daily'
#   Data shape for clustering: (213, 519)
#   Clustering successful. Labels: Counter({np.int64(1): 43, np.int64(0): 40, np.int64(2): 39, np.int64(7): 32, np.int64(5): 31, np.int64(3): 13, np.int64(6): 11, np.int64(4): 4})
#   Silhouette: 0.046, Balance ratio: 0.093
#   ✅ Success! Silhouette: 0.046
#
# --- Combination 14/48 ---
# Params: {'method': 'kmeans', 'n_clusters': 8, 'window': 1, 'aggregation': '3day', 'linkage': 'not_applicable'}
#   Using dataframe '3day' for aggregation '3day'
#   Data shape for clustering: (213, 241)
#   Clustering successful. Labels: Counter({np.int64(0): 51, np.int64(2): 42, np.int64(6): 33, np.int64(7): 25, np.int64(1): 20, np.int64(5): 18, np.int64(3): 12, np.int64(4): 12})
#   Silhouette: 0.021, Balance ratio: 0.235
#   ✅ Success! Silhouette: 0.021
#
# --- Combination 15/48 ---
# Params: {'method': 'kmeans', 'n_clusters': 8, 'window': 7, 'aggregation': 'daily', 'linkage': 'not_applicable'}
#   Using dataframe 'full' for aggregation 'daily'
#   Applied 7-period smoothing: (520, 213) → (514, 213)
#   Data shape for clustering: (213, 513)
#   Clustering successful. Labels: Counter({np.int64(4): 46, np.int64(2): 46, np.int64(6): 27, np.int64(7): 26, np.int64(0): 26, np.int64(3): 23, np.int64(1): 13, np.int64(5): 6})
#   Silhouette: -0.011, Balance ratio: 0.130
#   ✅ Success! Silhouette: -0.011
#
# --- Combination 16/48 ---
# Params: {'method': 'kmeans', 'n_clusters': 8, 'window': 7, 'aggregation': '3day', 'linkage': 'not_applicable'}
#   Using dataframe '3day' for aggregation '3day'
#   Applied 7-period smoothing: (242, 213) → (236, 213)
#   Data shape for clustering: (213, 235)
#   Clustering successful. Labels: Counter({np.int64(4): 39, np.int64(7): 35, np.int64(2): 33, np.int64(6): 29, np.int64(0): 24, np.int64(3): 20, np.int64(1): 17, np.int64(5): 16})
#   Silhouette: 0.012, Balance ratio: 0.410
#   ✅ Success! Silhouette: 0.012
#
# --- Combination 17/48 ---
# Params: {'method': 'kmeans', 'n_clusters': 8, 'window': 14, 'aggregation': 'daily', 'linkage': 'not_applicable'}
#   Using dataframe 'full' for aggregation 'daily'
#   Applied 14-period smoothing: (520, 213) → (507, 213)
#   Data shape for clustering: (213, 506)
#   Clustering successful. Labels: Counter({np.int64(4): 50, np.int64(0): 42, np.int64(7): 33, np.int64(2): 33, np.int64(6): 26, np.int64(1): 14, np.int64(5): 11, np.int64(3): 4})
#   Silhouette: -0.007, Balance ratio: 0.080
#   ✅ Success! Silhouette: -0.007
#
# --- Combination 18/48 ---
# Params: {'method': 'kmeans', 'n_clusters': 8, 'window': 14, 'aggregation': '3day', 'linkage': 'not_applicable'}
#   Using dataframe '3day' for aggregation '3day'
#   Applied 14-period smoothing: (242, 213) → (229, 213)
#   Data shape for clustering: (213, 228)
#   Clustering successful. Labels: Counter({np.int64(2): 48, np.int64(6): 43, np.int64(0): 34, np.int64(4): 31, np.int64(7): 24, np.int64(1): 19, np.int64(5): 9, np.int64(3): 5})
#   Silhouette: 0.028, Balance ratio: 0.104
#   ✅ Success! Silhouette: 0.028
#
# --- Combination 19/48 ---
# Params: {'method': 'kmeans', 'n_clusters': 10, 'window': 1, 'aggregation': 'daily', 'linkage': 'not_applicable'}
#   Using dataframe 'full' for aggregation 'daily'
#   Data shape for clustering: (213, 519)
#   Clustering successful. Labels: Counter({np.int64(6): 48, np.int64(2): 41, np.int64(1): 28, np.int64(4): 23, np.int64(3): 18, np.int64(9): 17, np.int64(8): 14, np.int64(0): 11, np.int64(7): 9, np.int64(5): 4})
#   Silhouette: 0.044, Balance ratio: 0.083
#   ✅ Success! Silhouette: 0.044
#
# --- Combination 20/48 ---
# Params: {'method': 'kmeans', 'n_clusters': 10, 'window': 1, 'aggregation': '3day', 'linkage': 'not_applicable'}
#   Using dataframe '3day' for aggregation '3day'
#   Data shape for clustering: (213, 241)
#   Clustering successful. Labels: Counter({np.int64(2): 40, np.int64(6): 37, np.int64(4): 31, np.int64(1): 29, np.int64(3): 21, np.int64(0): 18, np.int64(9): 14, np.int64(8): 10, np.int64(7): 7, np.int64(5): 6})
#   Silhouette: 0.033, Balance ratio: 0.150
#   ✅ Success! Silhouette: 0.033
#
# --- Combination 21/48 ---
# Params: {'method': 'kmeans', 'n_clusters': 10, 'window': 7, 'aggregation': 'daily', 'linkage': 'not_applicable'}
#   Using dataframe 'full' for aggregation 'daily'
#   Applied 7-period smoothing: (520, 213) → (514, 213)
#   Data shape for clustering: (213, 513)
#   Clustering successful. Labels: Counter({np.int64(6): 58, np.int64(2): 44, np.int64(4): 29, np.int64(1): 26, np.int64(8): 19, np.int64(3): 15, np.int64(9): 11, np.int64(5): 4, np.int64(0): 4, np.int64(7): 3})
#   Silhouette: 0.027, Balance ratio: 0.052
#   ✅ Success! Silhouette: 0.027
#
# --- Combination 22/48 ---
# Params: {'method': 'kmeans', 'n_clusters': 10, 'window': 7, 'aggregation': '3day', 'linkage': 'not_applicable'}
#   Using dataframe '3day' for aggregation '3day'
#   Applied 7-period smoothing: (242, 213) → (236, 213)
#   Data shape for clustering: (213, 235)
#   Clustering successful. Labels: Counter({np.int64(2): 42, np.int64(4): 36, np.int64(8): 29, np.int64(6): 25, np.int64(9): 22, np.int64(3): 22, np.int64(1): 19, np.int64(0): 11, np.int64(5): 6, np.int64(7): 1})
#   Silhouette: 0.006, Balance ratio: 0.024
#   ✅ Success! Silhouette: 0.006
#
# --- Combination 23/48 ---
# Params: {'method': 'kmeans', 'n_clusters': 10, 'window': 14, 'aggregation': 'daily', 'linkage': 'not_applicable'}
#   Using dataframe 'full' for aggregation 'daily'
#   Applied 14-period smoothing: (520, 213) → (507, 213)
#   Data shape for clustering: (213, 506)
#   Clustering successful. Labels: Counter({np.int64(2): 46, np.int64(8): 36, np.int64(6): 32, np.int64(4): 23, np.int64(9): 21, np.int64(3): 20, np.int64(1): 19, np.int64(0): 10, np.int64(5): 5, np.int64(7): 1})
#   Silhouette: 0.015, Balance ratio: 0.022
#   ✅ Success! Silhouette: 0.015
#
# --- Combination 24/48 ---
# Params: {'method': 'kmeans', 'n_clusters': 10, 'window': 14, 'aggregation': '3day', 'linkage': 'not_applicable'}
#   Using dataframe '3day' for aggregation '3day'
#   Applied 14-period smoothing: (242, 213) → (229, 213)
#   Data shape for clustering: (213, 228)
#   Clustering successful. Labels: Counter({np.int64(2): 66, np.int64(6): 30, np.int64(8): 28, np.int64(0): 26, np.int64(4): 22, np.int64(1): 15, np.int64(3): 10, np.int64(9): 8, np.int64(5): 5, np.int64(7): 3})
#   Silhouette: 0.027, Balance ratio: 0.045
#   ✅ Success! Silhouette: 0.027
#
# --- Combination 25/48 ---
# Params: {'method': 'ahc', 'n_clusters': 4, 'window': 1, 'aggregation': 'daily', 'linkage': 'average'}
#   Using dataframe 'full' for aggregation 'daily'
#   Data shape for clustering: (213, 519)
#   Clustering successful. Labels: Counter({np.int64(0): 208, np.int64(1): 3, np.int64(3): 1, np.int64(2): 1})
#   Silhouette: 0.064, Balance ratio: 0.005
#   ✅ Success! Silhouette: 0.064
#
# --- Combination 26/48 ---
# Params: {'method': 'ahc', 'n_clusters': 4, 'window': 1, 'aggregation': 'daily', 'linkage': 'complete'}
#   Using dataframe 'full' for aggregation 'daily'
#   Data shape for clustering: (213, 519)
#   Clustering successful. Labels: Counter({np.int64(0): 102, np.int64(3): 55, np.int64(1): 42, np.int64(2): 14})
#   Silhouette: 0.075, Balance ratio: 0.137
#   ✅ Success! Silhouette: 0.075
#
# --- Combination 27/48 ---
# Params: {'method': 'ahc', 'n_clusters': 4, 'window': 1, 'aggregation': '3day', 'linkage': 'average'}
#   Using dataframe '3day' for aggregation '3day'
#   Data shape for clustering: (213, 241)
#   Clustering successful. Labels: Counter({np.int64(1): 208, np.int64(0): 3, np.int64(2): 1, np.int64(3): 1})
#   Silhouette: 0.071, Balance ratio: 0.005
#   ✅ Success! Silhouette: 0.071
#
# --- Combination 28/48 ---
# Params: {'method': 'ahc', 'n_clusters': 4, 'window': 1, 'aggregation': '3day', 'linkage': 'complete'}
#   Using dataframe '3day' for aggregation '3day'
#   Data shape for clustering: (213, 241)
#   Clustering successful. Labels: Counter({np.int64(1): 69, np.int64(3): 59, np.int64(2): 55, np.int64(0): 30})
#   Silhouette: 0.076, Balance ratio: 0.435
#   ✅ Success! Silhouette: 0.076
#
# --- Combination 29/48 ---
# Params: {'method': 'ahc', 'n_clusters': 4, 'window': 7, 'aggregation': 'daily', 'linkage': 'average'}
#   Using dataframe 'full' for aggregation 'daily'
#   Applied 7-period smoothing: (520, 213) → (514, 213)
#   Data shape for clustering: (213, 513)
#   Clustering successful. Labels: Counter({np.int64(0): 209, np.int64(1): 2, np.int64(2): 1, np.int64(3): 1})
#   Silhouette: 0.088, Balance ratio: 0.005
#   ✅ Success! Silhouette: 0.088
#
# --- Combination 30/48 ---
# Params: {'method': 'ahc', 'n_clusters': 4, 'window': 7, 'aggregation': 'daily', 'linkage': 'complete'}
#   Using dataframe 'full' for aggregation 'daily'
#   Applied 7-period smoothing: (520, 213) → (514, 213)
#   Data shape for clustering: (213, 513)
#   Clustering successful. Labels: Counter({np.int64(0): 77, np.int64(1): 73, np.int64(3): 58, np.int64(2): 5})
#   Silhouette: 0.076, Balance ratio: 0.065
#   ✅ Success! Silhouette: 0.076
#
# --- Combination 31/48 ---
# Params: {'method': 'ahc', 'n_clusters': 4, 'window': 7, 'aggregation': '3day', 'linkage': 'average'}
#   Using dataframe '3day' for aggregation '3day'
#   Applied 7-period smoothing: (242, 213) → (236, 213)
#   Data shape for clustering: (213, 235)
#   Clustering successful. Labels: Counter({np.int64(2): 204, np.int64(0): 7, np.int64(3): 1, np.int64(1): 1})
#   Silhouette: 0.097, Balance ratio: 0.005
#   ✅ Success! Silhouette: 0.097
#
# --- Combination 32/48 ---
# Params: {'method': 'ahc', 'n_clusters': 4, 'window': 7, 'aggregation': '3day', 'linkage': 'complete'}
#   Using dataframe '3day' for aggregation '3day'
#   Applied 7-period smoothing: (242, 213) → (236, 213)
#   Data shape for clustering: (213, 235)
#   Clustering successful. Labels: Counter({np.int64(0): 82, np.int64(3): 78, np.int64(2): 47, np.int64(1): 6})
#   Silhouette: 0.053, Balance ratio: 0.073
#   ✅ Success! Silhouette: 0.053
#
# --- Combination 33/48 ---
# Params: {'method': 'ahc', 'n_clusters': 4, 'window': 14, 'aggregation': 'daily', 'linkage': 'average'}
#   Using dataframe 'full' for aggregation 'daily'
#   Applied 14-period smoothing: (520, 213) → (507, 213)
#   Data shape for clustering: (213, 506)
#   Clustering successful. Labels: Counter({np.int64(2): 204, np.int64(0): 7, np.int64(3): 1, np.int64(1): 1})
#   Silhouette: 0.100, Balance ratio: 0.005
#   ✅ Success! Silhouette: 0.100
#
# --- Combination 34/48 ---
# Params: {'method': 'ahc', 'n_clusters': 4, 'window': 14, 'aggregation': 'daily', 'linkage': 'complete'}
#   Using dataframe 'full' for aggregation 'daily'
#   Applied 14-period smoothing: (520, 213) → (507, 213)
#   Data shape for clustering: (213, 506)
#   Clustering successful. Labels: Counter({np.int64(1): 106, np.int64(2): 55, np.int64(0): 47, np.int64(3): 5})
#   Silhouette: 0.078, Balance ratio: 0.047
#   ✅ Success! Silhouette: 0.078
#
# --- Combination 35/48 ---
# Params: {'method': 'ahc', 'n_clusters': 4, 'window': 14, 'aggregation': '3day', 'linkage': 'average'}
#   Using dataframe '3day' for aggregation '3day'
#   Applied 14-period smoothing: (242, 213) → (229, 213)
#   Data shape for clustering: (213, 228)
#   Clustering successful. Labels: Counter({np.int64(1): 194, np.int64(2): 16, np.int64(0): 2, np.int64(3): 1})
#   Silhouette: 0.103, Balance ratio: 0.005
#   ✅ Success! Silhouette: 0.103
#
# --- Combination 36/48 ---
# Params: {'method': 'ahc', 'n_clusters': 4, 'window': 14, 'aggregation': '3day', 'linkage': 'complete'}
#   Using dataframe '3day' for aggregation '3day'
#   Applied 14-period smoothing: (242, 213) → (229, 213)
#   Data shape for clustering: (213, 228)
#   Clustering successful. Labels: Counter({np.int64(0): 112, np.int64(2): 71, np.int64(1): 17, np.int64(3): 13})
#   Silhouette: 0.058, Balance ratio: 0.116
#   ✅ Success! Silhouette: 0.058
#
# --- Combination 37/48 ---
# Params: {'method': 'ahc', 'n_clusters': 6, 'window': 1, 'aggregation': 'daily', 'linkage': 'average'}
#   Using dataframe 'full' for aggregation 'daily'
#   Data shape for clustering: (213, 519)
#   Clustering successful. Labels: Counter({np.int64(1): 204, np.int64(0): 3, np.int64(2): 2, np.int64(4): 2, np.int64(3): 1, np.int64(5): 1})
#   Silhouette: 0.059, Balance ratio: 0.005
#   ✅ Success! Silhouette: 0.059
#
# --- Combination 38/48 ---
# Params: {'method': 'ahc', 'n_clusters': 6, 'window': 1, 'aggregation': 'daily', 'linkage': 'complete'}
#   Using dataframe 'full' for aggregation 'daily'
#   Data shape for clustering: (213, 519)
#   Clustering successful. Labels: Counter({np.int64(3): 88, np.int64(0): 55, np.int64(5): 25, np.int64(1): 17, np.int64(4): 14, np.int64(2): 14})
#   Silhouette: 0.089, Balance ratio: 0.159
#   ✅ Success! Silhouette: 0.089
#
# --- Combination 39/48 ---
# Params: {'method': 'ahc', 'n_clusters': 6, 'window': 1, 'aggregation': '3day', 'linkage': 'average'}
#   Using dataframe '3day' for aggregation '3day'
#   Data shape for clustering: (213, 241)
#   Clustering successful. Labels: Counter({np.int64(2): 205, np.int64(0): 3, np.int64(1): 2, np.int64(4): 1, np.int64(5): 1, np.int64(3): 1})
#   Silhouette: 0.062, Balance ratio: 0.005
#   ✅ Success! Silhouette: 0.062
#
# --- Combination 40/48 ---
# Params: {'method': 'ahc', 'n_clusters': 6, 'window': 1, 'aggregation': '3day', 'linkage': 'complete'}
#   Using dataframe '3day' for aggregation '3day'
#   Data shape for clustering: (213, 241)
#   Clustering successful. Labels: Counter({np.int64(3): 59, np.int64(2): 55, np.int64(0): 55, np.int64(1): 18, np.int64(5): 14, np.int64(4): 12})
#   Silhouette: 0.086, Balance ratio: 0.203
#   ✅ Success! Silhouette: 0.086
#
# --- Combination 41/48 ---
# Params: {'method': 'ahc', 'n_clusters': 6, 'window': 7, 'aggregation': 'daily', 'linkage': 'average'}
#   Using dataframe 'full' for aggregation 'daily'
#   Applied 7-period smoothing: (520, 213) → (514, 213)
#   Data shape for clustering: (213, 513)
#   Clustering successful. Labels: Counter({np.int64(0): 207, np.int64(1): 2, np.int64(5): 1, np.int64(2): 1, np.int64(4): 1, np.int64(3): 1})
#   Silhouette: 0.081, Balance ratio: 0.005
#   ✅ Success! Silhouette: 0.081
#
# --- Combination 42/48 ---
# Params: {'method': 'ahc', 'n_clusters': 6, 'window': 7, 'aggregation': 'daily', 'linkage': 'complete'}
#   Using dataframe 'full' for aggregation 'daily'
#   Applied 7-period smoothing: (520, 213) → (514, 213)
#   Data shape for clustering: (213, 513)
#   Clustering successful. Labels: Counter({np.int64(1): 58, np.int64(0): 43, np.int64(5): 39, np.int64(3): 34, np.int64(4): 34, np.int64(2): 5})
#   Silhouette: 0.082, Balance ratio: 0.086
#   ✅ Success! Silhouette: 0.082
#
# --- Combination 43/48 ---
# Params: {'method': 'ahc', 'n_clusters': 6, 'window': 7, 'aggregation': '3day', 'linkage': 'average'}
#   Using dataframe '3day' for aggregation '3day'
#   Applied 7-period smoothing: (242, 213) → (236, 213)
#   Data shape for clustering: (213, 235)
#   Clustering successful. Labels: Counter({np.int64(2): 202, np.int64(0): 6, np.int64(5): 2, np.int64(3): 1, np.int64(4): 1, np.int64(1): 1})
#   Silhouette: 0.072, Balance ratio: 0.005
#   ✅ Success! Silhouette: 0.072
#
# --- Combination 44/48 ---
# Params: {'method': 'ahc', 'n_clusters': 6, 'window': 7, 'aggregation': '3day', 'linkage': 'complete'}
#   Using dataframe '3day' for aggregation '3day'
#   Applied 7-period smoothing: (242, 213) → (236, 213)
#   Data shape for clustering: (213, 235)
#   Clustering successful. Labels: Counter({np.int64(3): 78, np.int64(0): 48, np.int64(4): 34, np.int64(2): 30, np.int64(5): 17, np.int64(1): 6})
#   Silhouette: 0.062, Balance ratio: 0.077
#   ✅ Success! Silhouette: 0.062
#
# --- Combination 45/48 ---
# Params: {'method': 'ahc', 'n_clusters': 6, 'window': 14, 'aggregation': 'daily', 'linkage': 'average'}
#   Using dataframe 'full' for aggregation 'daily'
#   Applied 14-period smoothing: (520, 213) → (507, 213)
#   Data shape for clustering: (213, 506)
#   Clustering successful. Labels: Counter({np.int64(0): 202, np.int64(2): 6, np.int64(5): 2, np.int64(3): 1, np.int64(4): 1, np.int64(1): 1})
#   Silhouette: 0.080, Balance ratio: 0.005
#   ✅ Success! Silhouette: 0.080
#
# --- Combination 46/48 ---
# Params: {'method': 'ahc', 'n_clusters': 6, 'window': 14, 'aggregation': 'daily', 'linkage': 'complete'}
#   Using dataframe 'full' for aggregation 'daily'
#   Applied 14-period smoothing: (520, 213) → (507, 213)
#   Data shape for clustering: (213, 506)
#   Clustering successful. Labels: Counter({np.int64(5): 68, np.int64(2): 55, np.int64(0): 40, np.int64(1): 38, np.int64(4): 7, np.int64(3): 5})
#   Silhouette: 0.072, Balance ratio: 0.074
#   ✅ Success! Silhouette: 0.072
#
# --- Combination 47/48 ---
# Params: {'method': 'ahc', 'n_clusters': 6, 'window': 14, 'aggregation': '3day', 'linkage': 'average'}
#   Using dataframe '3day' for aggregation '3day'
#   Applied 14-period smoothing: (242, 213) → (229, 213)
#   Data shape for clustering: (213, 228)
#   Clustering successful. Labels: Counter({np.int64(0): 194, np.int64(1): 13, np.int64(2): 3, np.int64(4): 1, np.int64(3): 1, np.int64(5): 1})
#   Silhouette: 0.092, Balance ratio: 0.005
#   ✅ Success! Silhouette: 0.092
#
# --- Combination 48/48 ---
# Params: {'method': 'ahc', 'n_clusters': 6, 'window': 14, 'aggregation': '3day', 'linkage': 'complete'}
#   Using dataframe '3day' for aggregation '3day'
#   Applied 14-period smoothing: (242, 213) → (229, 213)
#   Data shape for clustering: (213, 228)
#   Clustering successful. Labels: Counter({np.int64(2): 99, np.int64(0): 61, np.int64(1): 17, np.int64(3): 13, np.int64(4): 13, np.int64(5): 10})
#   Silhouette: 0.071, Balance ratio: 0.101
#   ✅ Success! Silhouette: 0.071
#
# --- Combination 49/48 ---
# Params: {'method': 'ahc', 'n_clusters': 8, 'window': 1, 'aggregation': 'daily', 'linkage': 'average'}
#   Using dataframe 'full' for aggregation 'daily'
#   Data shape for clustering: (213, 519)
#   Clustering successful. Labels: Counter({np.int64(1): 144, np.int64(3): 60, np.int64(2): 2, np.int64(0): 2, np.int64(4): 2, np.int64(7): 1, np.int64(6): 1, np.int64(5): 1})
#   Silhouette: 0.091, Balance ratio: 0.007
#   ✅ Success! Silhouette: 0.091
#
# --- Combination 50/48 ---
# Params: {'method': 'ahc', 'n_clusters': 8, 'window': 1, 'aggregation': 'daily', 'linkage': 'complete'}
#   Using dataframe 'full' for aggregation 'daily'
#   Data shape for clustering: (213, 519)
#   Clustering successful. Labels: Counter({np.int64(7): 88, np.int64(6): 32, np.int64(5): 25, np.int64(2): 23, np.int64(0): 17, np.int64(4): 14, np.int64(3): 12, np.int64(1): 2})
#   Silhouette: 0.099, Balance ratio: 0.023
#   ✅ Success! Silhouette: 0.099
#
# --- Combination 51/48 ---
# Params: {'method': 'ahc', 'n_clusters': 8, 'window': 1, 'aggregation': '3day', 'linkage': 'average'}
#   Using dataframe '3day' for aggregation '3day'
#   Data shape for clustering: (213, 241)
#   Clustering successful. Labels: Counter({np.int64(0): 203, np.int64(3): 2, np.int64(2): 2, np.int64(1): 2, np.int64(6): 1, np.int64(4): 1, np.int64(5): 1, np.int64(7): 1})
#   Silhouette: 0.046, Balance ratio: 0.005
#   ✅ Success! Silhouette: 0.046
#
# --- Combination 52/48 ---
# Params: {'method': 'ahc', 'n_clusters': 8, 'window': 1, 'aggregation': '3day', 'linkage': 'complete'}
#   Using dataframe '3day' for aggregation '3day'
#   Data shape for clustering: (213, 241)
#   Clustering successful. Labels: Counter({np.int64(0): 59, np.int64(6): 55, np.int64(1): 39, np.int64(2): 16, np.int64(7): 15, np.int64(5): 14, np.int64(4): 12, np.int64(3): 3})
#   Silhouette: 0.099, Balance ratio: 0.051
#   ✅ Success! Silhouette: 0.099
#
# --- Combination 53/48 ---
# Params: {'method': 'ahc', 'n_clusters': 8, 'window': 7, 'aggregation': 'daily', 'linkage': 'average'}
#   Using dataframe 'full' for aggregation 'daily'
#   Applied 7-period smoothing: (520, 213) → (514, 213)
#   Data shape for clustering: (213, 513)
#   Clustering successful. Labels: Counter({np.int64(0): 201, np.int64(2): 5, np.int64(1): 2, np.int64(5): 1, np.int64(6): 1, np.int64(7): 1, np.int64(4): 1, np.int64(3): 1})
#   Silhouette: 0.058, Balance ratio: 0.005
#   ✅ Success! Silhouette: 0.058
#
# --- Combination 54/48 ---
# Params: {'method': 'ahc', 'n_clusters': 8, 'window': 7, 'aggregation': 'daily', 'linkage': 'complete'}
#   Using dataframe 'full' for aggregation 'daily'
#   Applied 7-period smoothing: (520, 213) → (514, 213)
#   Data shape for clustering: (213, 513)
#   Clustering successful. Labels: Counter({np.int64(1): 58, np.int64(2): 39, np.int64(3): 34, np.int64(4): 34, np.int64(7): 20, np.int64(6): 13, np.int64(5): 10, np.int64(0): 5})
#   Silhouette: 0.088, Balance ratio: 0.086
#   ✅ Success! Silhouette: 0.088
#
# --- Combination 55/48 ---
# Params: {'method': 'ahc', 'n_clusters': 8, 'window': 7, 'aggregation': '3day', 'linkage': 'average'}
#   Using dataframe '3day' for aggregation '3day'
#   Applied 7-period smoothing: (242, 213) → (236, 213)
#   Data shape for clustering: (213, 235)
#   Clustering successful. Labels: Counter({np.int64(0): 195, np.int64(1): 7, np.int64(5): 3, np.int64(6): 3, np.int64(2): 2, np.int64(7): 1, np.int64(4): 1, np.int64(3): 1})
#   Silhouette: 0.062, Balance ratio: 0.005
#   ✅ Success! Silhouette: 0.062
#
# --- Combination 56/48 ---
# Params: {'method': 'ahc', 'n_clusters': 8, 'window': 7, 'aggregation': '3day', 'linkage': 'complete'}
#   Using dataframe '3day' for aggregation '3day'
#   Applied 7-period smoothing: (242, 213) → (236, 213)
#   Data shape for clustering: (213, 235)
#   Clustering successful. Labels: Counter({np.int64(3): 78, np.int64(4): 34, np.int64(2): 32, np.int64(7): 24, np.int64(5): 17, np.int64(6): 16, np.int64(1): 6, np.int64(0): 6})
#   Silhouette: 0.057, Balance ratio: 0.077
#   ✅ Success! Silhouette: 0.057
#
# --- Combination 57/48 ---
# Params: {'method': 'ahc', 'n_clusters': 8, 'window': 14, 'aggregation': 'daily', 'linkage': 'average'}
#   Using dataframe 'full' for aggregation 'daily'
#   Applied 14-period smoothing: (520, 213) → (507, 213)
#   Data shape for clustering: (213, 506)
#   Clustering successful. Labels: Counter({np.int64(2): 150, np.int64(1): 51, np.int64(0): 6, np.int64(5): 2, np.int64(7): 1, np.int64(4): 1, np.int64(6): 1, np.int64(3): 1})
#   Silhouette: 0.101, Balance ratio: 0.007
#   ✅ Success! Silhouette: 0.101
#
# --- Combination 58/48 ---
# Params: {'method': 'ahc', 'n_clusters': 8, 'window': 14, 'aggregation': 'daily', 'linkage': 'complete'}
#   Using dataframe 'full' for aggregation 'daily'
#   Applied 14-period smoothing: (520, 213) → (507, 213)
#   Data shape for clustering: (213, 506)
#   Clustering successful. Labels: Counter({np.int64(5): 68, np.int64(0): 38, np.int64(1): 38, np.int64(6): 27, np.int64(3): 17, np.int64(2): 13, np.int64(4): 7, np.int64(7): 5})
#   Silhouette: 0.089, Balance ratio: 0.074
#   ✅ Success! Silhouette: 0.089
#
# --- Combination 59/48 ---
# Params: {'method': 'ahc', 'n_clusters': 8, 'window': 14, 'aggregation': '3day', 'linkage': 'average'}
#   Using dataframe '3day' for aggregation '3day'
#   Applied 14-period smoothing: (242, 213) → (229, 213)
#   Data shape for clustering: (213, 228)
#   Clustering successful. Labels: Counter({np.int64(2): 152, np.int64(1): 42, np.int64(6): 12, np.int64(0): 3, np.int64(4): 1, np.int64(7): 1, np.int64(3): 1, np.int64(5): 1})
#   Silhouette: 0.107, Balance ratio: 0.007
#   ✅ Success! Silhouette: 0.107
#
# --- Combination 60/48 ---
# Params: {'method': 'ahc', 'n_clusters': 8, 'window': 14, 'aggregation': '3day', 'linkage': 'complete'}
#   Using dataframe '3day' for aggregation '3day'
#   Applied 14-period smoothing: (242, 213) → (229, 213)
#   Data shape for clustering: (213, 228)
#   Clustering successful. Labels: Counter({np.int64(2): 99, np.int64(0): 33, np.int64(6): 28, np.int64(3): 13, np.int64(1): 13, np.int64(7): 11, np.int64(5): 10, np.int64(4): 6})
#   Silhouette: 0.065, Balance ratio: 0.061
#   ✅ Success! Silhouette: 0.065
#
# --- Combination 61/48 ---
# Params: {'method': 'ahc', 'n_clusters': 10, 'window': 1, 'aggregation': 'daily', 'linkage': 'average'}
#   Using dataframe 'full' for aggregation 'daily'
#   Data shape for clustering: (213, 519)
#   Clustering successful. Labels: Counter({np.int64(0): 144, np.int64(3): 60, np.int64(1): 2, np.int64(7): 1, np.int64(9): 1, np.int64(8): 1, np.int64(4): 1, np.int64(6): 1, np.int64(5): 1, np.int64(2): 1})
#   Silhouette: 0.085, Balance ratio: 0.007
#   ✅ Success! Silhouette: 0.085
#
# --- Combination 62/48 ---
# Params: {'method': 'ahc', 'n_clusters': 10, 'window': 1, 'aggregation': 'daily', 'linkage': 'complete'}
#   Using dataframe 'full' for aggregation 'daily'
#   Data shape for clustering: (213, 519)
#   Clustering successful. Labels: Counter({np.int64(7): 88, np.int64(6): 32, np.int64(5): 25, np.int64(4): 21, np.int64(9): 14, np.int64(8): 13, np.int64(3): 12, np.int64(2): 4, np.int64(1): 2, np.int64(0): 2})
#   Silhouette: 0.097, Balance ratio: 0.023
#   ✅ Success! Silhouette: 0.097
#
# --- Combination 63/48 ---
# Params: {'method': 'ahc', 'n_clusters': 10, 'window': 1, 'aggregation': '3day', 'linkage': 'average'}
#   Using dataframe '3day' for aggregation '3day'
#   Data shape for clustering: (213, 241)
#   Clustering successful. Labels: Counter({np.int64(2): 124, np.int64(1): 76, np.int64(4): 3, np.int64(8): 2, np.int64(0): 2, np.int64(3): 2, np.int64(6): 1, np.int64(9): 1, np.int64(5): 1, np.int64(7): 1})
#   Silhouette: 0.068, Balance ratio: 0.008
#   ✅ Success! Silhouette: 0.068
#
# --- Combination 64/48 ---
# Params: {'method': 'ahc', 'n_clusters': 10, 'window': 1, 'aggregation': '3day', 'linkage': 'complete'}
#   Using dataframe '3day' for aggregation '3day'
#   Data shape for clustering: (213, 241)
#   Clustering successful. Labels: Counter({np.int64(2): 55, np.int64(4): 31, np.int64(8): 28, np.int64(9): 27, np.int64(0): 16, np.int64(7): 15, np.int64(5): 14, np.int64(6): 12, np.int64(1): 12, np.int64(3): 3})
#   Silhouette: 0.090, Balance ratio: 0.055
#   ✅ Success! Silhouette: 0.090
#
# --- Combination 65/48 ---
# Params: {'method': 'ahc', 'n_clusters': 10, 'window': 7, 'aggregation': 'daily', 'linkage': 'average'}
#   Using dataframe 'full' for aggregation 'daily'
#   Applied 7-period smoothing: (520, 213) → (514, 213)
#   Data shape for clustering: (213, 513)
#   Clustering successful. Labels: Counter({np.int64(0): 134, np.int64(4): 66, np.int64(2): 5, np.int64(1): 2, np.int64(5): 1, np.int64(8): 1, np.int64(6): 1, np.int64(7): 1, np.int64(9): 1, np.int64(3): 1})
#   Silhouette: 0.071, Balance ratio: 0.007
#   ✅ Success! Silhouette: 0.071
#
# --- Combination 66/48 ---
# Params: {'method': 'ahc', 'n_clusters': 10, 'window': 7, 'aggregation': 'daily', 'linkage': 'complete'}
#   Using dataframe 'full' for aggregation 'daily'
#   Applied 7-period smoothing: (520, 213) → (514, 213)
#   Data shape for clustering: (213, 513)
#   Clustering successful. Labels: Counter({np.int64(2): 39, np.int64(9): 39, np.int64(1): 34, np.int64(0): 34, np.int64(7): 20, np.int64(3): 19, np.int64(6): 13, np.int64(5): 10, np.int64(8): 3, np.int64(4): 2})
#   Silhouette: 0.111, Balance ratio: 0.051
#   ✅ Success! Silhouette: 0.111
#
# --- Combination 67/48 ---
# Params: {'method': 'ahc', 'n_clusters': 10, 'window': 7, 'aggregation': '3day', 'linkage': 'average'}
#   Using dataframe '3day' for aggregation '3day'
#   Applied 7-period smoothing: (242, 213) → (236, 213)
#   Data shape for clustering: (213, 235)
#   Clustering successful. Labels: Counter({np.int64(0): 141, np.int64(1): 52, np.int64(3): 7, np.int64(5): 3, np.int64(6): 3, np.int64(2): 2, np.int64(4): 2, np.int64(7): 1, np.int64(9): 1, np.int64(8): 1})
#   Silhouette: 0.083, Balance ratio: 0.007
#   ✅ Success! Silhouette: 0.083
#
# --- Combination 68/48 ---
# Params: {'method': 'ahc', 'n_clusters': 10, 'window': 7, 'aggregation': '3day', 'linkage': 'complete'}
#   Using dataframe '3day' for aggregation '3day'
#   Applied 7-period smoothing: (242, 213) → (236, 213)
#   Data shape for clustering: (213, 235)
#   Clustering successful. Labels: Counter({np.int64(0): 78, np.int64(4): 34, np.int64(2): 32, np.int64(1): 24, np.int64(5): 17, np.int64(6): 16, np.int64(8): 4, np.int64(7): 3, np.int64(9): 3, np.int64(3): 2})
#   Silhouette: 0.061, Balance ratio: 0.026
#   ✅ Success! Silhouette: 0.061
#
# --- Combination 69/48 ---
# Params: {'method': 'ahc', 'n_clusters': 10, 'window': 14, 'aggregation': 'daily', 'linkage': 'average'}
#   Using dataframe 'full' for aggregation 'daily'
#   Applied 14-period smoothing: (520, 213) → (507, 213)
#   Data shape for clustering: (213, 506)
#   Clustering successful. Labels: Counter({np.int64(4): 146, np.int64(1): 51, np.int64(0): 4, np.int64(2): 3, np.int64(3): 3, np.int64(5): 2, np.int64(7): 1, np.int64(9): 1, np.int64(6): 1, np.int64(8): 1})
#   Silhouette: 0.089, Balance ratio: 0.007
#   ✅ Success! Silhouette: 0.089
#
# --- Combination 70/48 ---
# Params: {'method': 'ahc', 'n_clusters': 10, 'window': 14, 'aggregation': 'daily', 'linkage': 'complete'}
#   Using dataframe 'full' for aggregation 'daily'
#   Applied 14-period smoothing: (520, 213) → (507, 213)
#   Data shape for clustering: (213, 506)
#   Clustering successful. Labels: Counter({np.int64(5): 68, np.int64(0): 38, np.int64(6): 27, np.int64(9): 22, np.int64(3): 17, np.int64(2): 13, np.int64(8): 9, np.int64(4): 7, np.int64(1): 7, np.int64(7): 5})
#   Silhouette: 0.086, Balance ratio: 0.074
#   ✅ Success! Silhouette: 0.086
#
# --- Combination 71/48 ---
# Params: {'method': 'ahc', 'n_clusters': 10, 'window': 14, 'aggregation': '3day', 'linkage': 'average'}
#   Using dataframe '3day' for aggregation '3day'
#   Applied 14-period smoothing: (242, 213) → (229, 213)
#   Data shape for clustering: (213, 228)
#   Clustering successful. Labels: Counter({np.int64(0): 152, np.int64(6): 40, np.int64(2): 12, np.int64(1): 2, np.int64(4): 2, np.int64(9): 1, np.int64(8): 1, np.int64(7): 1, np.int64(3): 1, np.int64(5): 1})
#   Silhouette: 0.091, Balance ratio: 0.007
#   ✅ Success! Silhouette: 0.091
#
# --- Combination 72/48 ---
# Params: {'method': 'ahc', 'n_clusters': 10, 'window': 14, 'aggregation': '3day', 'linkage': 'complete'}
#   Using dataframe '3day' for aggregation '3day'
#   Applied 14-period smoothing: (242, 213) → (229, 213)
#   Data shape for clustering: (213, 228)
#   Clustering successful. Labels: Counter({np.int64(2): 64, np.int64(4): 35, np.int64(0): 28, np.int64(6): 17, np.int64(8): 16, np.int64(3): 13, np.int64(1): 13, np.int64(7): 11, np.int64(5): 10, np.int64(9): 6})
#   Silhouette: 0.086, Balance ratio: 0.094
#   ✅ Success! Silhouette: 0.086
#
# === SUMMARY ===
# Total combinations tested: 72
# Successful results: 72
